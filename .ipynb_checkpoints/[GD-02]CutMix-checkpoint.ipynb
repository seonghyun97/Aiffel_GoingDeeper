# %% [markdown]
# # [GD-02] 이미지 어디까지 우려볼까?

# %% [markdown]
# # 00. Import and Define Function

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# image 전처리 함수
def normalize_and_resize_img(image, label):
    # Normalizes images: `uint8` -> `float32`
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

# Basic augmentation(좌우반전, 명도변화)
def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.clip_by_value(image, 0, 1)
    return image, label

def onehot(image, label):
    label = tf.one_hot(label, num_classes)
    return image, label

'''Cut Mix'''
def get_clip_box(image_a, image_b):
    # image.shape = (height, width, channel)
    image_size_x = 224
    image_size_y = 224
    
    # get center of box
    x = tf.cast(tf.random.uniform([], 0, image_size_x), tf.int32)
    y = tf.cast(tf.random.uniform([], 0, image_size_y), tf.int32)

    # get width, height of box
    width = tf.cast(image_size_x*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)
    height = tf.cast(image_size_y*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)
    
    # clip box in image and get minmax bbox
    x_min = tf.math.maximum(0, x-width//2)
    y_min = tf.math.maximum(0, y-height//2)
    x_max = tf.math.minimum(image_size_x, x+width//2)
    y_max = tf.math.minimum(image_size_y, y+width//2)
    
    return x_min, y_min, x_max, y_max

# mix two images
def mix_2_images(image_a, image_b, x_min, y_min, x_max, y_max):
    image_size_x = image_a.shape[1]
    image_size_y = image_a.shape[0] 
    middle_left = image_a[y_min:y_max, 0:x_min, :] # image_b의 왼쪽 바깥 영역
    middle_center = image_b[y_min:y_max, x_min:x_max, :]  # image_b의 안쪽 영역
    middle_right = image_a[y_min:y_max, x_max:image_size_x, :] # image_b의 오른쪽 바깥 영역
    middle = tf.concat([middle_left,middle_center,middle_right], axis=1)
    top = image_a[0:y_min, :, :]
    bottom = image_a[y_max:image_size_y, :, :]
    mixed_img = tf.concat([top, middle, bottom],axis=0)
    
    return mixed_img

# mix two labels
def mix_2_labels(label_a, label_b, x_min, y_min, x_max, y_max, num_classes=120):
    image_size_x = 224
    image_size_y = 224
    mixed_area = (x_max-x_min)*(y_max-y_min)
    total_area = image_size_x*image_size_y
    ratio = tf.cast(mixed_area/total_area, tf.float32)

    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_label = (1-ratio)*label_a + ratio*label_b
    return mixed_label

def cutmix(image, label, prob=1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        x_min, y_min, x_max, y_max = get_clip_box(image_a, image_b)
        mixed_imgs.append(mix_2_images(image_a, image_b, x_min, y_min, x_max, y_max))
        mixed_labels.append(mix_2_labels(label_a, label_b, x_min, y_min, x_max, y_max))

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs), (batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels), (batch_size, num_classes))
    return mixed_imgs, mixed_labels

'''Mixup'''
# function for mixup
def mixup_2_images(image_a, image_b, label_a, label_b):
    ratio = tf.random.uniform([], 0, 1)
    
    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_image= (1-ratio)*image_a + ratio*image_b
    mixed_label = (1-ratio)*label_a + ratio*label_b
    
    return mixed_image, mixed_label

def mixup(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        idx = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_a = image[i]
        image_b = image[idx]
        label_a = label[i]
        label_b = label[idx]
        mixed_img, mixed_label = mixup_2_images(image_a, image_b, label_a, label_b)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs),(batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels),(batch_size, num_classes))
    return mixed_imgs, mixed_labels

# 데이터셋(ds)을 가공하는 메인함수
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(normalize_and_resize_img, num_parallel_calls=2)
    
    if not is_test and with_aug: # basic augmentation
        ds = ds.map(augment)
        
    ds = ds.batch(batch_size)
    if not is_test and with_cutmix: # cutmix
        ds = ds.map(cutmix, num_parallel_calls=2)
    elif not is_test and with_mixup: # mixup
        ds = ds.map(mixup, num_parallel_calls=2)
    else:
        ds = ds.map(onehot, num_parallel_calls=2)
        
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# Gpu 확인
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 01. Data

# %% [markdown]
# ### 01.1 Data load

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# %%
tfds.show_examples(ds_train, ds_info)

# %% [markdown]
# ### 01.2 Data Preprocessing

# %%
num_classes = ds_info.features["label"].num_classes

# %%
ds_train_no_aug = apply_normalize_on_dataset(ds_train, with_aug=False)
ds_train_aug = apply_normalize_on_dataset(ds_train, with_aug=True)
ds_train_cut = apply_normalize_on_dataset(ds_train, with_cutmix=True)
ds_train_mix = apply_normalize_on_dataset(ds_train, with_mixup=True)

ds_test = apply_normalize_on_dataset(ds_test, is_test=True)

# %% [markdown]
# ## 02. Model

# %% [markdown]
# ### 02.1 No Augmentaion

# %%
resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### 02.2 Basic Augmentaion

# %%
aug_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### 02.3 CutMix

# %%
cut_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### 02.4 Mixup

# %%
mix_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ## 03. Train

# %%
EPOCH = 20  # Augentation 적용 효과를 확인하기 위해 필요한 epoch 수

# %% [markdown]
# ### 03.1 No Augmentaion

# %%
resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

history_resnet50_no_aug = resnet50.fit(
    ds_train_no_aug, # augmentation 적용하지 않은 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/20
# 750/750 [==============================] - 164s 204ms/step - loss: 2.2283 - accuracy: 0.4424 - val_loss: 3.7290 - val_accuracy: 0.1542
# Epoch 2/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.7881 - accuracy: 0.7783 - val_loss: 1.0923 - val_accuracy: 0.6754
# Epoch 3/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.2540 - accuracy: 0.9453 - val_loss: 0.9934 - val_accuracy: 0.7118
# Epoch 4/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0744 - accuracy: 0.9932 - val_loss: 0.9131 - val_accuracy: 0.7378
# Epoch 5/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0291 - accuracy: 0.9983 - val_loss: 0.9114 - val_accuracy: 0.7406
# Epoch 6/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0181 - accuracy: 0.9993 - val_loss: 0.9608 - val_accuracy: 0.7362
# Epoch 7/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0141 - accuracy: 0.9993 - val_loss: 0.9524 - val_accuracy: 0.7395
# Epoch 8/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0115 - accuracy: 0.9994 - val_loss: 0.9560 - val_accuracy: 0.7401
# Epoch 9/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0086 - accuracy: 0.9999 - val_loss: 0.9513 - val_accuracy: 0.7407
# Epoch 10/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0073 - accuracy: 0.9998 - val_loss: 0.9569 - val_accuracy: 0.7439
# Epoch 11/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0066 - accuracy: 0.9997 - val_loss: 0.9685 - val_accuracy: 0.7427
# Epoch 12/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 1.0067 - val_accuracy: 0.7392
# Epoch 13/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0058 - accuracy: 0.9996 - val_loss: 0.9812 - val_accuracy: 0.7421
# Epoch 14/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0061 - accuracy: 0.9996 - val_loss: 1.0078 - val_accuracy: 0.7409
# Epoch 15/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0118 - accuracy: 0.9988 - val_loss: 1.0626 - val_accuracy: 0.7266
# Epoch 16/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 1.0294 - val_accuracy: 0.7362
# Epoch 17/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 1.0100 - val_accuracy: 0.7425
# Epoch 18/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0123 - val_accuracy: 0.7427
# Epoch 19/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.0186 - val_accuracy: 0.7428
# Epoch 20/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 1.0175 - val_accuracy: 0.7430

# %% [markdown]
# ### 03.2 Basic Augmentaion

# %%
aug_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

history_resnet50_aug = aug_resnet50.fit(
    ds_train_aug, # augmentation 적용한 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 159s 204ms/step - loss: 2.2816 - accuracy: 0.4312 - val_loss: 2.8920 - val_accuracy: 0.2804
# Epoch 2/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.9573 - accuracy: 0.7250 - val_loss: 1.1748 - val_accuracy: 0.6574
# Epoch 3/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.5048 - accuracy: 0.8635 - val_loss: 1.0792 - val_accuracy: 0.6834
# Epoch 4/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.2785 - accuracy: 0.9352 - val_loss: 1.0599 - val_accuracy: 0.6996
# Epoch 5/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.1567 - accuracy: 0.9677 - val_loss: 1.0451 - val_accuracy: 0.7058
# Epoch 6/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0919 - accuracy: 0.9862 - val_loss: 0.9976 - val_accuracy: 0.7224
# Epoch 7/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0571 - accuracy: 0.9927 - val_loss: 1.0469 - val_accuracy: 0.7199
# Epoch 8/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0368 - accuracy: 0.9967 - val_loss: 0.9634 - val_accuracy: 0.7427
# Epoch 9/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0341 - accuracy: 0.9962 - val_loss: 0.9611 - val_accuracy: 0.7462
# Epoch 10/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0204 - accuracy: 0.9983 - val_loss: 0.9787 - val_accuracy: 0.7409
# Epoch 11/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0148 - accuracy: 0.9992 - val_loss: 0.9552 - val_accuracy: 0.7534
# Epoch 12/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0127 - accuracy: 0.9992 - val_loss: 0.9644 - val_accuracy: 0.7487
# Epoch 13/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0116 - accuracy: 0.9992 - val_loss: 0.9722 - val_accuracy: 0.7529
# Epoch 14/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0082 - accuracy: 0.9996 - val_loss: 0.9757 - val_accuracy: 0.7529
# Epoch 15/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0080 - accuracy: 0.9995 - val_loss: 0.9793 - val_accuracy: 0.7514
# Epoch 16/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0080 - accuracy: 0.9995 - val_loss: 0.9802 - val_accuracy: 0.7480
# Epoch 17/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0078 - accuracy: 0.9995 - val_loss: 1.0280 - val_accuracy: 0.7397
# Epoch 18/20
# 750/750 [==============================] - 167s 223ms/step - loss: 0.0204 - accuracy: 0.9967 - val_loss: 1.1493 - val_accuracy: 0.7077
# Epoch 19/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0074 - accuracy: 0.9998 - val_loss: 1.0118 - val_accuracy: 0.7515
# Epoch 20/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0053 - accuracy: 0.9998 - val_loss: 1.0053 - val_accuracy: 0.7524

# %% [markdown]
# ### 03.3 CutMix

# %%
cut_resnet50.compile(
    loss= 'categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

history_cut_aug = cut_resnet50.fit(
    ds_train_aug, # augmentation 적용한 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 159s 204ms/step - loss: 2.2942 - accuracy: 0.4276 - val_loss: 3.2325 - val_accuracy: 0.2373
# Epoch 2/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.9475 - accuracy: 0.7278 - val_loss: 1.2451 - val_accuracy: 0.6308
# Epoch 3/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.5045 - accuracy: 0.8607 - val_loss: 1.0005 - val_accuracy: 0.7107
# Epoch 4/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.2602 - accuracy: 0.9383 - val_loss: 1.1929 - val_accuracy: 0.6639
# Epoch 5/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.1408 - accuracy: 0.9720 - val_loss: 1.0019 - val_accuracy: 0.7158
# Epoch 6/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0818 - accuracy: 0.9875 - val_loss: 0.9925 - val_accuracy: 0.7281
# Epoch 7/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0499 - accuracy: 0.9941 - val_loss: 0.9450 - val_accuracy: 0.7354
# Epoch 8/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0335 - accuracy: 0.9962 - val_loss: 0.9942 - val_accuracy: 0.7340
# Epoch 9/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0266 - accuracy: 0.9977 - val_loss: 1.0185 - val_accuracy: 0.7304
# Epoch 10/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0176 - accuracy: 0.9989 - val_loss: 0.9783 - val_accuracy: 0.7415
# Epoch 11/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0159 - accuracy: 0.9985 - val_loss: 1.0477 - val_accuracy: 0.7311
# Epoch 12/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0138 - accuracy: 0.9989 - val_loss: 1.0047 - val_accuracy: 0.7395
# Epoch 13/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0125 - accuracy: 0.9988 - val_loss: 1.0042 - val_accuracy: 0.7413
# Epoch 14/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0097 - accuracy: 0.9992 - val_loss: 1.0037 - val_accuracy: 0.7456
# Epoch 15/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0083 - accuracy: 0.9994 - val_loss: 1.0170 - val_accuracy: 0.7446
# Epoch 16/20
# 750/750 [==============================] - 167s 223ms/step - loss: 0.0081 - accuracy: 0.9992 - val_loss: 1.0395 - val_accuracy: 0.7379
# Epoch 17/20
# 750/750 [==============================] - 167s 223ms/step - loss: 0.0056 - accuracy: 0.9998 - val_loss: 1.0190 - val_accuracy: 0.7449
# Epoch 18/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0054 - accuracy: 0.9999 - val_loss: 1.0453 - val_accuracy: 0.7425
# Epoch 19/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 1.0322 - val_accuracy: 0.7420
# Epoch 20/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 1.0439 - val_accuracy: 0.7417

# %% [markdown]
# ### 03.4 Mixup

# %%
mix_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

history_mix_aug = mix_resnet50.fit(
    ds_train_aug, # augmentation 적용한 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 159s 203ms/step - loss: 2.3036 - accuracy: 0.4205 - val_loss: 3.2756 - val_accuracy: 0.2274
# Epoch 2/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.9332 - accuracy: 0.7338 - val_loss: 1.3748 - val_accuracy: 0.6051
# Epoch 3/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.5060 - accuracy: 0.8627 - val_loss: 1.0971 - val_accuracy: 0.6746
# Epoch 4/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.2600 - accuracy: 0.9372 - val_loss: 0.9796 - val_accuracy: 0.7135
# Epoch 5/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.1500 - accuracy: 0.9689 - val_loss: 0.9913 - val_accuracy: 0.7178
# Epoch 6/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0869 - accuracy: 0.9873 - val_loss: 0.9114 - val_accuracy: 0.7359
# Epoch 7/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0515 - accuracy: 0.9932 - val_loss: 0.9833 - val_accuracy: 0.7308
# Epoch 8/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0340 - accuracy: 0.9971 - val_loss: 0.9649 - val_accuracy: 0.7397
# Epoch 9/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0286 - accuracy: 0.9972 - val_loss: 0.9862 - val_accuracy: 0.7348
# Epoch 10/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0192 - accuracy: 0.9988 - val_loss: 0.9339 - val_accuracy: 0.7519
# Epoch 11/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0155 - accuracy: 0.9983 - val_loss: 0.9660 - val_accuracy: 0.7418
# Epoch 12/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.9542 - val_accuracy: 0.7528
# Epoch 13/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0157 - accuracy: 0.9979 - val_loss: 1.1605 - val_accuracy: 0.7045
# Epoch 14/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0376 - accuracy: 0.9947 - val_loss: 1.0259 - val_accuracy: 0.7330
# Epoch 15/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0136 - accuracy: 0.9991 - val_loss: 0.9915 - val_accuracy: 0.7470
# Epoch 16/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.9681 - val_accuracy: 0.7541
# Epoch 17/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 1.0436 - val_accuracy: 0.7338
# Epoch 18/20
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0068 - accuracy: 0.9996 - val_loss: 0.9772 - val_accuracy: 0.7531
# Epoch 19/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.9903 - val_accuracy: 0.7493
# Epoch 20/20
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 1.0037 - val_accuracy: 0.7485

# %% [markdown]
# ## 04. Visualize

# %%
plt.plot(history_resnet50_no_aug.history['val_accuracy'], 'r')
plt.plot(history_resnet50_aug.history['val_accuracy'], 'b')
plt.plot(history_cut_aug.history['val_accuracy'], color='limegreen')
plt.plot(history_mix_aug.history['val_accuracy'], color='violet')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['No Augmentation', 'With Augmentation','cut','mix'], loc='upper left')
plt.grid(True)
plt.ylim(0.50, 0.80)    # 출력하고자 하는  Accuracy 범위를 지정해 주세요. 
#plt.ylim(0.72, 0.76)  # EPOCH=20으로 진행한다면 이 범위가 적당합니다. 
plt.show()

# %% [markdown]
# ## 05. 회고

# %% [markdown]
# 1. model paratmeter
#     - project를 진행하면서 가장 많은 시간을 썼던 부분은 함수가 서로 얽혀있는 상황에서 parameter을 맞춰주는 것이었다. parmater가 잘못 연결되어있다면 함수를 타고타고 들어가서 어느 부분이 잘못되었는지 확인하는 것이 중요하다.
#
# 2. Accrancy
#     - 4개의 model의 Accurancy를 비교해봤을 때 엄청난 차이는 있지 않고 0.75를 향하여 비슷하게 수렴한다. 왜 이렇게 될까 생각해보았을 때 이미 훈련이 된 model이기에 augumentation을 하여 data증강을 한 것이 별의미가 없을 수도 있다는 생각을 하였다.
#     - 다양한 실험을 해보고 싶었지만 시간이 상당히 들었던 실험이었다.
